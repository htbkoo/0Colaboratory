# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /opt/conda/lib/python3.7/site-packages (0.9.0)
# Requirement already satisfied: shapely>=1.6 in /opt/conda/lib/python3.7/site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: fiona>=1.8 in /opt/conda/lib/python3.7/site-packages (from geopandas) (1.8.18)
# Requirement already satisfied: pyproj>=2.2.0 in /opt/conda/lib/python3.7/site-packages (from geopandas) (2.6.1.post1)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.7/site-packages (from geopandas) (1.2.2)
# Requirement already satisfied: attrs>=17 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Requirement already satisfied: click<8,>=4.0 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (0.7.1)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: munch in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas) (1.19.5)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/crime-in-berlin-2012-2019/Berlin_crimes.csv

# %%
import seaborn as sns

# %%
filepath = "../input/crime-in-berlin-2012-2019/Berlin_crimes.csv"

df = pd.read_csv(filepath)
df
# Out:
#       Year       District    Code                                Location  \
# 0     2012          Mitte   10111                          Tiergarten Süd
# 1     2012          Mitte   10112                       Regierungsviertel
# 2     2012          Mitte   10113                          Alexanderplatz
# 3     2012          Mitte   10114                       Brunnenstraße Süd
# 4     2012          Mitte   10221                             Moabit West
# ...    ...            ...     ...                                     ...
# 1195  2019  Reinickendorf  123012  Nord 2 - Waidmannslust/Wittenau/Lübars
# 1196  2019  Reinickendorf  123021               MV 1 - Märkisches Viertel
# 1197  2019  Reinickendorf  123022                 MV 2 - Rollbergsiedlung
# 1198  2019  Reinickendorf  123043      West 3 - Borsigwalde/Freie Scholle
# 1199  2019  Reinickendorf  129900           Bezirk (Rd), nicht zuzuordnen
#
#       Robbery  Street_robbery  Injury  Agg_assault  Threat  Theft  Car  \
# 0          70              46     586          194     118   2263   18
# 1          65              29     474          123     142   3203   10
# 2         242             136    1541          454     304   8988   81
# 3          52              25     254           60      66   1916   86
# 4         130              51     629          185     199   2470   94
# ...       ...             ...     ...          ...     ...    ...  ...
# 1195       34              19     372           85     123   1160   30
# 1196       42              22     491          123     187   1100   51
# 1197        6               4      84           19      34    293   13
# 1198        8               4      95           18      43    492   21
# 1199        3               2      14            7       4     59    0
#
#       From_car  Bike  Burglary  Fire  Arson  Damage  Graffiti  Drugs  Local
# 0          328   120        68    16      4     273        26    171   1032
# 1          307   170        37    10      4     380       124     98    870
# 2          792   822       275    49     27    1538       522    435   3108
# 3          192   396       131    14      5     428       122    213    752
# 4          410   325       161    42     22     516        64    259   1403
# ...        ...   ...       ...   ...    ...     ...       ...    ...    ...
# 1195       135   150        93    16      3     306        74    110    728
# 1196       224    76        40    39     19     286        11     73    986
# 1197        36    18        34     5      2     156        56     21    212
# 1198        96    69        38     6      1      79         8     31    218
# 1199         7    15         0     1      0       7         3      9     21
#
# [1200 rows x 20 columns]

# %%
df_2019 = df[df["Year"]==2019].set_index("Location")
df_2019
# Out:
#                                         Year       District    Code  Robbery  \
# Location
# Tiergarten Süd                          2019          Mitte   10111       60
# Regierungsviertel                       2019          Mitte   10112       42
# Alexanderplatz                          2019          Mitte   10113      173
# Brunnenstraße Süd                       2019          Mitte   10114       40
# Moabit West                             2019          Mitte   10221       66
# ...                                      ...            ...     ...      ...
# Nord 2 - Waidmannslust/Wittenau/Lübars  2019  Reinickendorf  123012       34
# MV 1 - Märkisches Viertel               2019  Reinickendorf  123021       42
# MV 2 - Rollbergsiedlung                 2019  Reinickendorf  123022        6
# West 3 - Borsigwalde/Freie Scholle      2019  Reinickendorf  123043        8
# Bezirk (Rd), nicht zuzuordnen           2019  Reinickendorf  129900        3
#
#                                         Street_robbery  Injury  Agg_assault  \
# Location
# Tiergarten Süd                                      35     365           92
# Regierungsviertel                                   20     554          136
# Alexanderplatz                                     102    1966          500
# Brunnenstraße Süd                                   29     268           64
# Moabit West                                         29     685          210
# ...                                                ...     ...          ...
# Nord 2 - Waidmannslust/Wittenau/Lübars              19     372           85
# MV 1 - Märkisches Viertel                           22     491          123
# MV 2 - Rollbergsiedlung                              4      84           19
# West 3 - Borsigwalde/Freie Scholle                   4      95           18
# Bezirk (Rd), nicht zuzuordnen                        2      14            7
#
#                                         Threat  Theft  Car  From_car  Bike  \
# Location
# Tiergarten Süd                             128   2271   15       198   296
# Regierungsviertel                          152   3692   13       172   352
# Alexanderplatz                             420  11233   63       587   940
# Brunnenstraße Süd                           79   1859   39       182   361
# Moabit West                                202   2107   47       322   326
# ...                                        ...    ...  ...       ...   ...
# Nord 2 - Waidmannslust/Wittenau/Lübars     123   1160   30       135   150
# MV 1 - Märkisches Viertel                  187   1100   51       224    76
# MV 2 - Rollbergsiedlung                     34    293   13        36    18
# West 3 - Borsigwalde/Freie Scholle          43    492   21        96    69
# Bezirk (Rd), nicht zuzuordnen                4     59    0         7    15
#
#                                         Burglary  Fire  Arson  Damage  \
# Location
# Tiergarten Süd                                55    13      6     347
# Regierungsviertel                             22    19      4     497
# Alexanderplatz                               137    43     12    1307
# Brunnenstraße Süd                             64    18      7     424
# Moabit West                                   93    28     15     641
# ...                                          ...   ...    ...     ...
# Nord 2 - Waidmannslust/Wittenau/Lübars        93    16      3     306
# MV 1 - Märkisches Viertel                     40    39     19     286
# MV 2 - Rollbergsiedlung                       34     5      2     156
# West 3 - Borsigwalde/Freie Scholle            38     6      1      79
# Bezirk (Rd), nicht zuzuordnen                  0     1      0       7
#
#                                         Graffiti  Drugs  Local
# Location
# Tiergarten Süd                                77    231    980
# Regierungsviertel                            162    170   1057
# Alexanderplatz                               381   1133   3813
# Brunnenstraße Süd                            172     86    902
# Moabit West                                   91    618   1409
# ...                                          ...    ...    ...
# Nord 2 - Waidmannslust/Wittenau/Lübars        74    110    728
# MV 1 - Märkisches Viertel                     11     73    986
# MV 2 - Rollbergsiedlung                       56     21    212
# West 3 - Borsigwalde/Freie Scholle             8     31    218
# Bezirk (Rd), nicht zuzuordnen                  3      9     21
#
# [150 rows x 19 columns]
