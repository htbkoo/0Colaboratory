# %%
import pandas as pd
import xgboost as xgb
import functools
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
DATA_FOLDER = "data"

# %%
train_data = pd.read_csv(f"{DATA_FOLDER}/train.csv")
train_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test_data = pd.read_csv(f"{DATA_FOLDER}/test.csv")
test_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %%
test_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
CATEGORICAL_COLUMNS = [
    "MSSubClass",
    "MSZoning",
    "Street",
    "Alley",
    "LotShape",
    "LandContour",
    "Utilities",
    "LotConfig",
    "LandSlope",
    "Neighborhood",
    "Condition1",
    "Condition2",
    "BldgType",
    "HouseStyle",
    "YearBuilt",
    "RoofStyle",
    "RoofMatl",
    "Exterior1st",
    "Exterior2nd",
    "MasVnrType",
    "ExterQual",
    "ExterCond",
    "Foundation",
    "BsmtQual",
    "BsmtCond",
    "BsmtExposure",
    "BsmtFinType1",
    "BsmtFinType2",
    "Heating",
    "HeatingQC",
    "CentralAir",
    "Electrical",
    "KitchenQual",
    "Functional",
    "FireplaceQu",
    "GarageType",
    "GarageFinish",
    "GarageQual",
    "GarageCond",
    "PavedDrive",
    "PoolQC",
    "Fence",
    "MiscFeature",
    "SaleType",
    "SaleCondition",
]

def convert_column_to_one_hot_encoding(df, column_name):
    return pd.concat([df,pd.get_dummies(df[column_name], prefix=column_name,dummy_na=True)],axis=1).drop([column_name],axis=1)

def convert_columns(dataset, columns):
    return functools.reduce(
        lambda df, column_name: convert_column_to_one_hot_encoding(df, column_name),
        columns,
        dataset,
    )

# %%
combined_encoded_data = convert_columns(pd.concat([train_data, test_data]), CATEGORICAL_COLUMNS)
combined_encoded_data
# Out:
#         Id  LotFrontage  LotArea  OverallQual  OverallCond  YearRemodAdd  \
# 0        1         65.0     8450            7            5          2003
# 1        2         80.0     9600            6            8          1976
# 2        3         68.0    11250            7            5          2002
# 3        4         60.0     9550            7            5          1970
# 4        5         84.0    14260            8            5          2000
# ...    ...          ...      ...          ...          ...           ...
# 1454  2915         21.0     1936            4            7          1970
# 1455  2916         21.0     1894            4            5          1970
# 1456  2917        160.0    20000            5            7          1996
# 1457  2918         62.0    10441            5            5          1992
# 1458  2919         74.0     9627            7            5          1994
#
#       MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  SaleType_Oth  \
# ...

# %%
encoded_train_data = combined_encoded_data[:len(train_data)]
encoded_train_data
# Out:
#         Id  LotFrontage  LotArea  OverallQual  OverallCond  YearRemodAdd  \
# 0        1         65.0     8450            7            5          2003
# 1        2         80.0     9600            6            8          1976
# 2        3         68.0    11250            7            5          2002
# 3        4         60.0     9550            7            5          1970
# 4        5         84.0    14260            8            5          2000
# ...    ...          ...      ...          ...          ...           ...
# 1455  1456         62.0     7917            6            5          2000
# 1456  1457         85.0    13175            6            6          1988
# 1457  1458         66.0     9042            7            9          2006
# 1458  1459         68.0     9717            5            6          1996
# 1459  1460         75.0     9937            5            6          1965
#
#       MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  SaleType_Oth  \
# ...

# %%
X = encoded_train_data.drop(['Id'], axis=1).drop(['SalePrice'], axis=1)
X
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearRemodAdd  \
# 0            65.0     8450            7            5          2003
# 1            80.0     9600            6            8          1976
# 2            68.0    11250            7            5          2002
# 3            60.0     9550            7            5          1970
# 4            84.0    14260            8            5          2000
# ...           ...      ...          ...          ...           ...
# 1455         62.0     7917            6            5          2000
# 1456         85.0    13175            6            6          1988
# 1457         66.0     9042            7            9          2006
# 1458         68.0     9717            5            6          1996
# 1459         75.0     9937            5            6          1965
#
#       MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  \
# 0          196.0       706.0         0.0      150.0        856.0  ...
# ...

# %%
y = train_data['SalePrice']
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
# Split into validation and training data
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

# %%
# specify parameters via map
dtrain = xgb.DMatrix(train_X.values, train_y.values)
dval = xgb.DMatrix(val_X.values)

# param = {'max_depth':2, 'eta':1, 'objective':'binary:logistic', "tree_method": "gpu_hist" }

param = {'max_depth':4, 'eta':0.001, "tree_method": "gpu_hist" }
num_round = 20000

bst = xgb.train(param, dtrain, num_round)

xgb_val_preds = bst.predict(dval)
rf_val_mae = mean_absolute_error(xgb_val_preds, val_y)

print("Validation MAE for Random Forest Model: {:,.0f}".format(rf_val_mae))

# After training, the model can be saved.
# bst.save_model('0001.model')
# Out:
# Validation MAE for Random Forest Model: 15,043

# %% [markdown]
# ---

# %% [markdown]
# ## TEST evaluation

# %%
encoded_test_data = combined_encoded_data[len(train_data):]
encoded_test_data
# Out:
#         Id  LotFrontage  LotArea  OverallQual  OverallCond  YearRemodAdd  \
# 0     1461         80.0    11622            5            6          1961
# 1     1462         81.0    14267            6            6          1958
# 2     1463         74.0    13830            5            5          1998
# 3     1464         78.0     9978            6            6          1998
# 4     1465         43.0     5005            8            5          1992
# ...    ...          ...      ...          ...          ...           ...
# 1454  2915         21.0     1936            4            7          1970
# 1455  2916         21.0     1894            4            5          1970
# 1456  2917        160.0    20000            5            7          1996
# 1457  2918         62.0    10441            5            5          1992
# 1458  2919         74.0     9627            7            5          1994
#
#       MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  SaleType_Oth  \
# ...

# %%
# create test_X which comes from test_data but includes only the columns you used for prediction.
# The list of columns is stored in a variable called features
# test_X = test_data[features]
test_X = encoded_test_data.drop(['Id'], axis=1).drop(['SalePrice'], axis=1)
test_X
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearRemodAdd  \
# 0            80.0    11622            5            6          1961
# 1            81.0    14267            6            6          1958
# 2            74.0    13830            5            5          1998
# 3            78.0     9978            6            6          1998
# 4            43.0     5005            8            5          1992
# ...           ...      ...          ...          ...           ...
# 1454         21.0     1936            4            7          1970
# 1455         21.0     1894            4            5          1970
# 1456        160.0    20000            5            7          1996
# 1457         62.0    10441            5            5          1992
# 1458         74.0     9627            7            5          1994
#
#       MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  \
# 0            0.0       468.0       144.0      270.0        882.0  ...
# ...

# %%
# read in data
dtest = xgb.DMatrix(test_X.values)

# make prediction
preds = bst.predict(dtest)

output = pd.DataFrame({'Id': test_data.Id,
                      'SalePrice': preds})
output.to_csv('submission.csv', index=False)
output.to_csv('submission_xgboost.csv', index=False)

# %% [markdown]
# ---

# %%
pd.get_dummies(train_data)
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  \
# ...

# %%
convert_columns(train_data, CATEGORICAL_COLUMNS).describe()
# Out:
#                 Id  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    70.049958   10516.828082     6.099315     5.575342
# std     421.610009    24.284752    9981.264932     1.382997     1.112799
# min       1.000000    21.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    59.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    69.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    80.000000   11601.500000     7.000000     6.000000
# max    1460.000000   313.000000  215245.000000    10.000000     9.000000
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count   1460.000000  1452.000000  1460.000000  1460.000000  1460.000000  ...
# mean    1984.865753   103.685262   443.639726    46.549315   567.240411  ...
# std       20.645407   181.066207   456.098091   161.319273   441.866955  ...
# ...

# %%
convert_columns(test_data, CATEGORICAL_COLUMNS).describe()
# Out:
#                 Id  LotFrontage       LotArea  OverallQual  OverallCond  \
# count  1459.000000  1232.000000   1459.000000  1459.000000  1459.000000
# mean   2190.000000    68.580357   9819.161069     6.078821     5.553804
# std     421.321334    22.376841   4955.517327     1.436812     1.113740
# min    1461.000000    21.000000   1470.000000     1.000000     1.000000
# 25%    1825.500000    58.000000   7391.000000     5.000000     5.000000
# 50%    2190.000000    67.000000   9399.000000     6.000000     5.000000
# 75%    2554.500000    80.000000  11517.500000     7.000000     6.000000
# max    2919.000000   200.000000  56600.000000    10.000000     9.000000
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count   1459.000000  1444.000000  1458.000000  1458.000000  1458.000000  ...
# mean    1983.662783   100.709141   439.203704    52.619342   554.294925  ...
# std       21.130467   177.625900   455.268042   176.753926   437.260486  ...
# ...
